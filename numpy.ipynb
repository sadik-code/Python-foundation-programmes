# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
scores=np.array([10,20,40,50,80,5,9,78])
print("array>50:",scores>20)
# Out:
# array>50: [False False  True  True  True False False  True]

# %%
import numpy as np
scores=np.array([10,20,40,50,80,5,9,78])
scores=np.where(scores>=50,"pass","fail")
print(scores)
# Out:
# ['fail' 'fail' 'fail' 'pass' 'pass' 'fail' 'fail' 'pass']

# %%
import numpy as np
x=np.array([[1,2],[3,4]])
y=np.array([[5,6],[7,8]])
result=np.concatenate((x,y))
print(result)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
import numpy as np
x=np.array([[1,2],[3,4]])
y=np.array([[5,6],[7,8]])
print(x*y)
# Out:
# [[ 5 12]
#  [21 32]]

# %%
import numpy as np
x=np.array([1,2])
y=np.array([5,6])
print(np.dot(x,y))
# Out:
# 17

# %%
import numpy as np
data=np.array([10,20,np.nan,40,50])

# %%
import numpy as np
x=np.array([[1,2],[3,4]])
y=np.array([[5,6],[7,8]])
print(x@y)
# Out:
# [[19 22]
#  [43 50]]

# %%
import numpy as np
rng=np.random.default_rng(42)
print("random integer :",rng.integer(1,10,size=5))
print("random floats:",rng.random(5))
print("normal distribution:",rng.normal(size=5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy as np
#       2 rng=np.random.default_rng(42)
# ----> 3 print("random integer :",rng.integer(1,10,size=5))
#       4 print("random floats:",rng.random(5))
#       5 print("normal distribution:",rng.normal(size=5))
#
# AttributeError: 'numpy.random._generator.Generator' object has no attribute 'integer'
